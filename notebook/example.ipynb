# %%
from collections import namedtuple

# %% [markdown]
# 1. Download url
# 2. Download folder (compressed file)
# 3. Extract folder (extracted file))
# 4. Train dataset folder
# 5. Test dataset folder

# %%
DataIngestionConfig=namedtuple("DataIngestionConfig",
["dataset_download_url","tgz_download_dir","raw_data_dir","ingested_train_dir","ingested_test_dir"])

# %%
data_ingestion_config = DataIngestionConfig(dataset_download_url="asfasdf",
tgz_download_dir='asdasd',
raw_data_dir="asdas",
ingested_train_dir="asdbfk",
ingested_test_dir="sadnjk"
)

# %%
data_ingestion_config
# Out:
# DataIngestionConfig(dataset_download_url='asfasdf', tgz_download_dir='asdasd', raw_data_dir='asdas', ingested_train_dir='asdbfk', ingested_test_dir='sadnjk')

# %%
("sdfjnksdf","sdwjkuf","asdfasd","wsdfbkiasd")
# Out:
# ('sdfjnksdf', 'sdwjkuf', 'asdfasd', 'wsdfbkiasd')

# %%
import yaml

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\notebook'

# %%
os.chdir('c:\\Users\\pbann\\ML-END-TO-END-PROJECT-')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\pbann\\ML-END-TO-END-PROJECT-'

# %%
config_file_path=os.path.join("config","config.yaml")

# %%
config_file_path
# Out:
# 'config\\config.yaml'

# %%
os.path.exists(config_file_path)
# Out:
# True

# %%
os.getcwd()
# Out:
# 'c:\\Users\\pbann\\ML-END-TO-END-PROJECT-'

# %%
config_info=None
with open(config_file_path,"rb") as yaml_file:
    config_info=yaml.safe_load(yaml_file)

# %%
config_info["data_ingestion_config"]
# Out:
# {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#  'raw_data_dir': 'raw_data',
#  'tgz_download_dir': 'tgz_data',
#  'ingested_dir': 'ingested_data',
#  'ingested_train_dir': 'train',
#  'ingested_test_dir': 'test'}

# %%
def read_yaml_file(file_path:str)->dict:
    """
    Reads a YAML file and returns the contents as a dictionary.
    file_path: str
    """
    try:
        with open(file_path, 'rb') as yaml_file:
            return yaml.safe_load(yaml_file)
    except Exception as e:
        raise e

# %%
config =read_yaml_file(config_file_path)

# %%
from housing.constant import *

# %%
TRAINING_PIPELINE_CONFIG_KEY
# Out:
# 'training_pipeline_config'

# %%
config[TRAINING_PIPELINE_CONFIG_KEY]
# Out:
# {'pipeline_name': 'housing', 'artifact_dir': 'artifact'}

# %%
config[TRAINING_PIPELINE_CONFIG_KEY][TRAINING_PIPELINE_NAME_KEY]
# Out:
# 'housing'

# %%
training_pipeline_config = config[TRAINING_PIPELINE_CONFIG_KEY]
artifact_dir = os.path.join(ROOT_DIR,
training_pipeline_config[TRAINING_PIPELINE_NAME_KEY],
training_pipeline_config[TRAINING_PIPELINE_ARTIFACT_DIR_KEY]
)

# %%
ROOT_DIR
# Out:
# 'c:\\Users\\pbann\\ML-END-TO-END-PROJECT-'

# %%
training_pipeline_config[TRAINING_PIPELINE_NAME_KEY]
# Out:
# 'housing'

# %%
training_pipeline_config[TRAINING_PIPELINE_ARTIFACT_DIR_KEY]
# Out:
# 'artifact'

# %%
artifact_dir
# Out:
# 'c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact'

# %%
from housing.config.configuration import Configuartion

# %%
os.getcwd()
# Out:
# 'c:\\Users\\pbann\\ML-END-TO-END-PROJECT-'

# %%
config = Configuartion(config_file_path="c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\config\\config.yaml")

# %%
config.get_training_pipeline_config()
# Out:
# TrainingPipelineConfig(artifact_dir='c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact')

# %%
training_pipeline_config=config.get_training_pipeline_config()

# %%
artifact_dir = training_pipeline_config.artifact_dir

# %%
DATA_INGESTION_ARTIFACT_DIR
# Out:
# 'data_ingestion'

# %%
CURRENT_TIME_STAMP
# Out:
# '2022-06-28-10-39-51'

# %%
from housing.constant import *

# %%
data_ingestion_info=config.config_info[DATA_INGESTION_CONFIG_KEY]

# %%
data_ingestion_info
# Out:
# {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#  'raw_data_dir': 'raw_data',
#  'tgz_download_dir': 'tgz_data',
#  'ingested_dir': 'ingested_data',
#  'ingested_train_dir': 'train',
#  'ingested_test_dir': 'test'}

# %%
from housing.constant import DATA_INGESTION_CONFIG_KEY

# %%
DATA_INGESTION_CONFIG_KEY
# Out:
# 'data_ingestion_config'

# %%
data_ingestion_info[DATA_INGESTION_DOWNLOAD_URL_KEY]
# Out:
# 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'

# %%
data_ingestion_info
# Out:
# {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#  'raw_data_dir': 'raw_data',
#  'tgz_download_dir': 'tgz_data',
#  'ingested_dir': 'ingested_data',
#  'ingested_train_dir': 'train',
#  'ingested_test_dir': 'test'}

# %%
config.get_data_ingestion_config()
# Out:
# DataIngestionConfig(dataset_download_url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz', tgz_download_dir='c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact\\data_ingestion\\2022-06-28-10-39-51\\tgz_data', raw_data_dir='c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact\\data_ingestion\\2022-06-28-10-39-51\\raw_data', ingested_train_dir='c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact\\data_ingestion\\2022-06-28-10-39-51\\ingested_data\\train', ingested_test_dir='c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact\\data_ingestion\\2022-06-28-10-39-51\\ingested_data\\test')

# %%
raise Exception("Testing exception")

# %%
from housing.config.configuration import Configuartion

# %%
config = Configuartion(config_file_path="c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\config\\config.yaml")

# %%
config.get_data_ingestion_config()
# Out:
# DataIngestionConfig(dataset_download_url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz', tgz_download_dir='c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact\\data_ingestion\\2022-06-28-10-39-51\\tgz_data', raw_data_dir='c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact\\data_ingestion\\2022-06-28-10-39-51\\raw_data', ingested_train_dir='c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact\\data_ingestion\\2022-06-28-10-39-51\\ingested_data\\train', ingested_test_dir='c:\\Users\\pbann\\ML-END-TO-END-PROJECT-\\housing\\artifact\\data_ingestion\\2022-06-28-10-39-51\\ingested_data\\test')
